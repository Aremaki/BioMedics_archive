# %%
import pstats

# %%
p = pstats.Stats("prof_out.prof")

p.sort_stats(pstats.SortKey.TIME).print_stats()
# Out:
# Tue Sep 19 14:54:51 2023    prof_out.prof
#
#          145348402 function calls (143854511 primitive calls) in 143.124 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       655   47.739    0.073   47.739    0.073 {method 'acquire' of '_thread.lock' objects}
#      2150   11.429    0.005   11.469    0.005 {method 'readlines' of '_io._IOBase' objects}
#     50972    8.922    0.000    8.922    0.000 {pandas._libs.ops.scalar_compare}
#   7572985    3.319    0.000    6.046    0.000 /export/home/cse200093/Jacques_Bio/super_pipe/py_files/extract_measurements_from_brat.py:117(is_overlapping)
# 15925908/15925737    2.902    0.000    4.255    0.000 {built-in method builtins.isinstance}
#         1    2.456    2.456   24.195   24.195 /export/home/cse200093/Jacques_Bio/super_pipe/py_files/extract_measurements_from_brat.py:125(remove_labels_from_label_key)
# ...
